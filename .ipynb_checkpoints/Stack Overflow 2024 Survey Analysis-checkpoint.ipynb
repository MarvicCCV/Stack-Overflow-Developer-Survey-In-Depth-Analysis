# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_csv('survey_results_public_part2.csv')

# %%
df
# Out:
#        ResponseId                      MainBranch              Age  \
# 0           32719  I am a developer by profession  25-34 years old
# 1           32720  I am a developer by profession  25-34 years old
# 2           32721  I am a developer by profession  25-34 years old
# 3           32722  I am a developer by profession  18-24 years old
# 4           32723  I am a developer by profession  45-54 years old
# ...           ...                             ...              ...
# 32714       65433  I am a developer by profession  18-24 years old
# 32715       65434  I am a developer by profession  25-34 years old
# 32716       65435  I am a developer by profession  25-34 years old
# 32717       65436  I am a developer by profession  18-24 years old
# 32718       65437     I code primarily as a hobby  18-24 years old
#
#                                               Employment  \
# 0                                    Employed, full-time
# ...

# %%
df_part1 = df.iloc[:len(df)//2]

# %%
df_part2 = df.iloc[len(df)//2:]

# %%
# Out:
# survey_results_public.csv_part1 was successfully deleted!
